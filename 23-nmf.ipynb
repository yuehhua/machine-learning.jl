# %% [markdown]
# # Non-negative matrix factorization

# %%
using NMF, Distances, RDatasets, Plots

# %% [markdown]
# ## Load data

# %%
iris = RDatasets.dataset("datasets", "iris")
first(iris, 6)
# Out:
# 6×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa       │

# %% [markdown]
# ## Preprocessing

# %%
X = Matrix(iris[:, 1:4])
# Out:
# 150×4 Array{Float64,2}:
#  5.1  3.5  1.4  0.2
#  4.9  3.0  1.4  0.2
#  4.7  3.2  1.3  0.2
#  4.6  3.1  1.5  0.2
#  5.0  3.6  1.4  0.2
#  5.4  3.9  1.7  0.4
#  4.6  3.4  1.4  0.3
#  5.0  3.4  1.5  0.2
#  4.4  2.9  1.4  0.2
#  4.9  3.1  1.5  0.1
#  5.4  3.7  1.5  0.2
#  4.8  3.4  1.6  0.2
#  4.8  3.0  1.4  0.1
#  ⋮
#  6.0  3.0  4.8  1.8
#  6.9  3.1  5.4  2.1
#  6.7  3.1  5.6  2.4
#  6.9  3.1  5.1  2.3
#  5.8  2.7  5.1  1.9
#  6.8  3.2  5.9  2.3
#  6.7  3.3  5.7  2.5
#  6.7  3.0  5.2  2.3
#  6.3  2.5  5.0  1.9
#  6.5  3.0  5.2  2.0
#  6.2  3.4  5.4  2.3
#  5.9  3.0  5.1  1.8

# %% [markdown]
# ## Model

# %%
k = 3
r = nnmf(X, k)
# Out:
# NMF.Result{Float64}([0.0278552 0.28137 0.0120363; 0.0300315 0.25018 0.00509944; … ; 0.087123 0.054667 0.187389; 0.0835394 0.0540176 0.156413], [63.5846 0.137464 46.1155 2.34697; 11.8276 11.7994 0.0959905 0.0; 0.000458743 14.7101 7.45738 11.0126], 100, false, 3.5538561599205765)

# %%
W = r.W
# Out:
# 150×3 Array{Float64,2}:
#  0.0278552  0.28137    0.0120363
#  0.0300315  0.25018    0.00509944
#  0.0259942  0.257149   0.0114121
#  0.0283829  0.238476   0.0174813
#  0.0264309  0.282313   0.0167052
#  0.0309771  0.290629   0.0312326
#  0.0251946  0.254865   0.0253576
#  0.0290553  0.26778    0.0150804
#  0.0272169  0.226544   0.0144942
#  0.0303484  0.252692   0.00652292
#  0.0297277  0.297084   0.0126794
#  0.0288309  0.255133   0.0227933
#  0.0291711  0.249268   0.00351683
#  ⋮
#  0.0806799  0.0730484  0.144994
#  0.0939142  0.0727061  0.156154
#  0.0953402  0.0463666  0.178671
#  0.090656   0.0822152  0.154932
#  0.0851404  0.0331901  0.155709
#  0.098741   0.042495   0.183801
#  0.0952471  0.0478642  0.190273
#  0.0911495  0.0648428  0.16032
#  0.0889199  0.0477334  0.136314
#  0.0892748  0.065888   0.153228
#  0.087123   0.054667   0.187389
#  0.0835394  0.0540176  0.156413

# %%
H = r.H
# Out:
# 3×4 Array{Float64,2}:
#  63.5846        0.137464  46.1155      2.34697
#  11.8276       11.7994     0.0959905   0.0
#   0.000458743  14.7101     7.45738    11.0126

# %% [markdown]
# ## Plot

# %%
heatmap(W)

# %%
heatmap(H)
